# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyD7MJZoXAv3ZJL3w5dmwe5KmUKbtVRX78Y"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"




def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

  youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)

  search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet",
    maxResults=max_results,
    location=location,
    locationRadius=location_radius

  ).execute()



  videos = []

  for search_result in search_response.get("items", []):
    if search_result["id"]["kind"] == "youtube#video":
      videos.append(search_result)
  try:
      nexttok = search_response["nextPageToken"]
      return(nexttok, videos)
  except Exception as e:
      nexttok = "last_page"
      return(nexttok, videos)

# %%
test = youtube_search("Art and Music")

# %%
video_dict = {'youID':[], 'title':[], 'description':[]}

# %%
def grab_videos(keyword, token=None):
    res = youtube_search(keyword)
    token = res[0]
    videos = res[1]
    for vid in videos:
        video_dict['youID'].append(vid['id']['videoId'])
        video_dict['title'].append(vid['snippet']['title'])
        video_dict['description'].append(vid['snippet']['description'])
        print ("added " + str(len(videos)) + " videos to a total of " + str(len(video_dict['youID'])))
    return token

# %%
token = grab_videos("Travel Blogs")
while token != "last_page":
    token = grab_videos("Travel Blogs", token=token)

# %%
token = grab_videos("Science and Technology")
while token != "last_page":
    token = grab_videos("Science and Technology", token=token)
# Out:
# added 50 videos to a total of 1
# added 50 videos to a total of 2
# added 50 videos to a total of 3
# added 50 videos to a total of 4
# added 50 videos to a total of 5
# added 50 videos to a total of 6
# added 50 videos to a total of 7
# added 50 videos to a total of 8
# added 50 videos to a total of 9
# added 50 videos to a total of 10
# added 50 videos to a total of 11
# added 50 videos to a total of 12
# added 50 videos to a total of 13
# added 50 videos to a total of 14
# added 50 videos to a total of 15
# added 50 videos to a total of 16
# added 50 videos to a total of 17
# added 50 videos to a total of 18
# added 50 videos to a total of 19
# added 50 videos to a total of 20
# added 50 videos to a total of 21
# added 50 videos to a total of 22
# added 50 videos to a total of 23
# added 50 videos to a total of 24
# added 50 videos to a total of 25
# added 50 videos to a total of 26
# added 50 videos to a total of 27
# added 50 videos to a total of 28
# ...

# %%
token = grab_videos("manufacturing")
while token != "last_page":
    token = grab_videos("manufacturing", token=token)

# %%
token = grab_videos("food")
while token != "last_page":
    token = grab_videos("food", token=token)

# %%
token = grab_videos("Art and Music")
while token != "last_page":
    token = grab_videos("Art and Music", token=token)

# %%
token = grab_videos("History")
while token != "last_page":
    token = grab_videos("History", token=token)
# Out:
# added 50 videos to a total of 1
# added 50 videos to a total of 2
# added 50 videos to a total of 3
# added 50 videos to a total of 4
# added 50 videos to a total of 5
# added 50 videos to a total of 6
# added 50 videos to a total of 7
# added 50 videos to a total of 8
# added 50 videos to a total of 9
# added 50 videos to a total of 10
# added 50 videos to a total of 11
# added 50 videos to a total of 12
# added 50 videos to a total of 13
# added 50 videos to a total of 14
# added 50 videos to a total of 15
# added 50 videos to a total of 16
# added 50 videos to a total of 17
# added 50 videos to a total of 18
# added 50 videos to a total of 19
# added 50 videos to a total of 20
# added 50 videos to a total of 21
# added 50 videos to a total of 22
# added 50 videos to a total of 23
# added 50 videos to a total of 24
# added 50 videos to a total of 25
# added 50 videos to a total of 26
# added 50 videos to a total of 27
# added 50 videos to a total of 28
# ...

# %%
token = grab_videos("Science and Technology")
while token != "last_page":
    token = grab_videos("Science and Technology", token=token)

# %%
print(video_dict)

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('Travel_blog_data.csv', header=False))

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('food_data.csv', header=False))

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('manufacturing_data.csv', header=False))

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('Science_data.csv', header=False))

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('history_data.csv', header=False))

# %%
import pandas as pd

(pd.DataFrame.from_dict(data=video_dict)
   .to_csv('Science_Technology_data.csv', header=False))
